# %% [markdown]
# About Dataset
# This dataset contains information about the top-rated 9,000 movies from The Movie Database (TMDB). It includes key details like movie titles, release dates, popularity, user ratings, and genre classifications. This dataset can be used to analyze trends in movie ratings, popularity, and genre distribution over time.
#
# Column Descriptions:
#
# id:
# A unique identifier for each movie on TMDB.
#
# title:
# The title of the movie.
#
# original_language:
# The language in which the movie was originally made. Common values include "en" for English, "fr" for French, etc.
#
# release_date:
# The date when the movie was released, in the format YYYY-MM-DD.
#
# vote_average:
# The average rating of the movie, based on user ratings on TMDB.
#
# vote_count:
# The total number of user votes or ratings that the movie has received.
#
# popularity:
# A measure of the movie's popularity on TMDB, based on factors like views, ratings, and social media mentions.
#
# overview:
# A brief summary or synopsis of the movie’s plot.
#
# genre_ids:
# A list of numeric IDs representing the genres of the movie.
#
# Genres:
# A list of the genres associated with the movie, expressed in human-readable format (e.g., Drama, Crime, History).

# %%
import pandas as pd

# %%
# Importando a base de dados

df = pd.read_csv('https://raw.githubusercontent.com/henriqueoffice/Top-rated-9000-movies-TMDB/refs/heads/main/top_rated_9000_movies_on_TMDB.csv')
df
# Out:
#          id                       title original_language release_date  \
# 0       278    The Shawshank Redemption                en   1994-09-23
# 1       238               The Godfather                en   1972-03-14
# 2       240       The Godfather Part II                en   1974-12-20
# 3       424            Schindler's List                en   1993-12-15
# 4       389                12 Angry Men                en   1957-04-10
# ...     ...                         ...               ...          ...
# 9625  12142           Alone in the Dark                en   2005-01-28
# 9626  13805              Disaster Movie                en   2008-08-29
# 9627  11059           House of the Dead                en   2003-04-11
# 9628  14164        Dragonball Evolution                en   2009-03-12
# 9629  40016  Birdemic: Shock and Terror                en   2010-02-27
#
#       vote_average  vote_count  popularity  \
# 0            8.706       26840     150.307
# 1            8.690       20373     122.973
# 2            8.575       12291      94.204
# 3            8.565       15695      74.615
# 4            8.546        8522      54.678
# ...            ...         ...         ...
# 9625         3.251         599      11.337
# 9626         3.179        1015      19.006
# 9627         3.129         379      12.745
# 9628         2.896        2016      20.904
# 9629         2.200         331       6.548
#
#                                                overview  \
# 0     Imprisoned in the 1940s for the double murder ...
# 1     Spanning the years 1945 to 1955, a chronicle o...
# 2     In the continuing saga of the Corleone crime f...
# 3     The true story of how businessman Oskar Schind...
# 4     The defense and the prosecution have rested an...
# ...                                                 ...
# 9625  Edward Carnby is a private investigator specia...
# 9626  Over the course of one evening, an unsuspectin...
# 9627  Set on an island off the coast, a techno rave ...
# 9628  On his 18th birthday, Goku receives a mystical...
# 9629  A platoon of eagles and vultures attacks the r...
#
#                   genre_ids                                             Genres
# 0                  [18, 80]                                 ['Drama', 'Crime']
# 1                  [18, 80]                                 ['Drama', 'Crime']
# 2                  [18, 80]                                 ['Drama', 'Crime']
# 3           [18, 36, 10752]                        ['Drama', 'History', 'War']
# 4                      [18]                                          ['Drama']
# ...                     ...                                                ...
# 9625           [28, 14, 27]                    ['Action', 'Fantasy', 'Horror']
# 9626                   [35]                                         ['Comedy']
# 9627           [27, 28, 53]                   ['Horror', 'Action', 'Thriller']
# 9628  [28, 12, 14, 878, 53]  ['Action', 'Adventure', 'Fantasy', 'Science Fi...
# 9629        [10749, 27, 53]                  ['Romance', 'Horror', 'Thriller']
#
# [9630 rows x 10 columns]

# %%
# Tratamento dos dados

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9630 entries, 0 to 9629
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 9630 non-null   int64
#  1   title              9630 non-null   object
#  2   original_language  9630 non-null   object
#  3   release_date       9630 non-null   object
#  4   vote_average       9630 non-null   float64
#  5   vote_count         9630 non-null   int64
#  6   popularity         9630 non-null   float64
#  7   overview           9630 non-null   object
#  8   genre_ids          9630 non-null   object
#  9   Genres             9630 non-null   object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 752.5+ KB

# %%
df.isnull().sum()
# Out:
# id                   0
# title                0
# original_language    0
# release_date         0
# vote_average         0
# vote_count           0
# popularity           0
# overview             0
# genre_ids            0
# Genres               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 117

# %%
filtro_duplicadas = df.duplicated()
df[filtro_duplicadas]
# Out:
#           id                                        title original_language  \
# 500   632322                                  All My Life                en
# 540    16859                      Kiki's Delivery Service                ja
# 544   323272                                     War Room                en
# 560    25606                           White Collar Blues                it
# 800   803700                          The Eight Mountains                it
# ...      ...                                          ...               ...
# 8210   44982                                           13                en
# 8297  305932                                     Expelled                en
# 8440  357096  I Spit on Your Grave III: Vengeance Is Mine                en
# 8885   61012                   Silent Hill: Revelation 3D                en
# 9212   11933                          Nothing but Trouble                en
#
#      release_date  vote_average  vote_count  popularity  \
# 500    2020-10-23         7.847         474      17.077
# 540    1989-07-29         7.826        3983      57.343
# 544    2015-08-28         7.822         506      34.532
# 560    1975-03-27         7.817         817       6.950
# 800    2022-12-21         7.687         675      15.020
# ...           ...           ...         ...         ...
# 8210   2010-03-12         5.836         795      11.430
# 8297   2014-12-12         5.809         447       6.774
# 8440   2015-10-01         5.748         925      32.152
# 8885   2012-10-10         5.523        1603      27.798
# 9212   1991-02-15         5.267         350      14.138
#
#                                                overview        genre_ids  \
# 500   It was a chance meeting started by one of Sol’...      [10749, 18]
# 540   A young witch, on her mandatory year of indepe...  [16, 10751, 14]
# 544   The family-friendly movie explores the transfo...             [18]
# 560   A good-natured but unlucky Italian is constant...             [35]
# 800   An epic journey of friendship and self-discove...             [18]
# ...                                                 ...              ...
# 8210  A naive young man assumes a dead man's identit...         [18, 53]
# 8297  Felix is a legendary prankster who gets expell...             [35]
# 8440  Jennifer Hills is still tormented by the bruta...         [27, 53]
# 8885  Heather Mason and her father have been on the ...   [53, 27, 9648]
# 9212  While attempting to seduce gorgeous lawyer Dia...         [35, 12]
#
#                                   Genres
# 500                 ['Romance', 'Drama']
# 540   ['Animation', 'Family', 'Fantasy']
# 544                            ['Drama']
# 560                           ['Comedy']
# 800                            ['Drama']
# ...                                  ...
# 8210               ['Drama', 'Thriller']
# 8297                          ['Comedy']
# 8440              ['Horror', 'Thriller']
# 8885   ['Thriller', 'Horror', 'Mystery']
# 9212             ['Comedy', 'Adventure']
#
# [117 rows x 10 columns]

# %%
df.groupby('title').get_group('War Room')
# Out:
#          id     title original_language release_date  vote_average  \
# 538  323272  War Room                en   2015-08-28         7.822
# 544  323272  War Room                en   2015-08-28         7.822
#
#      vote_count  popularity  \
# 538         506      34.532
# 544         506      34.532
#
#                                               overview genre_ids     Genres
# 538  The family-friendly movie explores the transfo...      [18]  ['Drama']
# 544  The family-friendly movie explores the transfo...      [18]  ['Drama']

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# id                   0
# title                0
# original_language    0
# release_date         0
# vote_average         0
# vote_count           0
# popularity           0
# overview             0
# genre_ids            0
# Genres               0
# dtype: int64

# %%
df['release_date'] = pd.to_datetime(df['release_date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9513 entries, 0 to 9629
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 9513 non-null   int64
#  1   title              9513 non-null   object
#  2   original_language  9513 non-null   object
#  3   release_date       9513 non-null   datetime64[ns]
#  4   vote_average       9513 non-null   float64
#  5   vote_count         9513 non-null   int64
#  6   popularity         9513 non-null   float64
#  7   overview           9513 non-null   object
#  8   genre_ids          9513 non-null   object
#  9   Genres             9513 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(5)
# memory usage: 817.5+ KB

# %%
df.sort_values(by='vote_average', ascending=False)
df.reset_index(inplace = True, drop = True)
df
# Out:
#          id                       title original_language release_date  \
# 0       278    The Shawshank Redemption                en   1994-09-23
# 1       238               The Godfather                en   1972-03-14
# 2       240       The Godfather Part II                en   1974-12-20
# 3       424            Schindler's List                en   1993-12-15
# 4       389                12 Angry Men                en   1957-04-10
# ...     ...                         ...               ...          ...
# 9508  12142           Alone in the Dark                en   2005-01-28
# 9509  13805              Disaster Movie                en   2008-08-29
# 9510  11059           House of the Dead                en   2003-04-11
# 9511  14164        Dragonball Evolution                en   2009-03-12
# 9512  40016  Birdemic: Shock and Terror                en   2010-02-27
#
#       vote_average  vote_count  popularity  \
# 0            8.706       26840     150.307
# 1            8.690       20373     122.973
# 2            8.575       12291      94.204
# 3            8.565       15695      74.615
# 4            8.546        8522      54.678
# ...            ...         ...         ...
# 9508         3.251         599      11.337
# 9509         3.179        1015      19.006
# 9510         3.129         379      12.745
# 9511         2.896        2016      20.904
# 9512         2.200         331       6.548
#
#                                                overview  \
# 0     Imprisoned in the 1940s for the double murder ...
# 1     Spanning the years 1945 to 1955, a chronicle o...
# 2     In the continuing saga of the Corleone crime f...
# 3     The true story of how businessman Oskar Schind...
# 4     The defense and the prosecution have rested an...
# ...                                                 ...
# 9508  Edward Carnby is a private investigator specia...
# 9509  Over the course of one evening, an unsuspectin...
# 9510  Set on an island off the coast, a techno rave ...
# 9511  On his 18th birthday, Goku receives a mystical...
# 9512  A platoon of eagles and vultures attacks the r...
#
#                   genre_ids                                             Genres
# 0                  [18, 80]                                 ['Drama', 'Crime']
# 1                  [18, 80]                                 ['Drama', 'Crime']
# 2                  [18, 80]                                 ['Drama', 'Crime']
# 3           [18, 36, 10752]                        ['Drama', 'History', 'War']
# 4                      [18]                                          ['Drama']
# ...                     ...                                                ...
# 9508           [28, 14, 27]                    ['Action', 'Fantasy', 'Horror']
# 9509                   [35]                                         ['Comedy']
# 9510           [27, 28, 53]                   ['Horror', 'Action', 'Thriller']
# 9511  [28, 12, 14, 878, 53]  ['Action', 'Adventure', 'Fantasy', 'Science Fi...
# 9512        [10749, 27, 53]                  ['Romance', 'Horror', 'Thriller']
#
# [9513 rows x 10 columns]

# %% [markdown]
# ---
#
# Distribuição de filmes por gênero
#
# ---

# %%
distribuicao_generos = df['Genres'].value_counts().nlargest(15)
distribuicao_generos
# Out:
# Genres
# ['Comedy']                        565
# ['Drama']                         545
# ['Drama', 'Romance']              262
# ['Comedy', 'Romance']             243
# ['Comedy', 'Drama']               218
# ['Horror', 'Thriller']            190
# ['Horror']                        149
# ['Comedy', 'Drama', 'Romance']    139
# ['Drama', 'Thriller']             127
# ['Drama', 'History']              121
# ['Drama', 'Comedy']               110
# ['Crime', 'Drama', 'Thriller']     90
# ['Action', 'Thriller']             87
# ['Romance', 'Comedy']              87
# ['Crime', 'Drama']                 79
# Name: count, dtype: int64

# %%
import plotly.graph_objects as go

# Criando um gráfico de colunas usando Plotly Graph Objects
fig = go.Figure()

fig.add_trace(go.Bar(x=distribuicao_generos.index, y=distribuicao_generos.values, text=distribuicao_generos.values, textposition='auto'))

fig.update_layout(title='Top 15 Gêneros',
                  xaxis_title='Gêneros', yaxis_title='Quantidade Filmes')

# Mostrando o gráfico
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="581cdb18-c255-4270-b651-3db4de5d94f5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("581cdb18-c255-4270-b651-3db4de5d94f5")) {                    Plotly.newPlot(                        "581cdb18-c255-4270-b651-3db4de5d94f5",                        [{"text":[565.0,545.0,262.0,243.0,218.0,190.0,149.0,139.0,127.0,121.0,110.0,90.0,87.0,87.0,79.0],"textposition":"auto","x":["['Comedy']","['Drama']","['Drama', 'Romance']","['Comedy', 'Romance']","['Comedy', 'Drama']","['Horror', 'Thriller']","['Horror']","['Comedy', 'Drama', 'Romance']","['Drama', 'Thriller']","['Drama', 'History']","['Drama', 'Comedy']","['Crime', 'Drama', 'Thriller']","['Action', 'Thriller']","['Romance', 'Comedy']","['Crime', 'Drama']"],"y":[565,545,262,243,218,190,149,139,127,121,110,90,87,87,79],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width ...

# %% [markdown]
# ---
#
# Distribuição de filmes por idioma
#
# ---

# %%
distribuicao_idiomas = df['original_language'].value_counts().nlargest(10)

# Criando um gráfico de colunas usando Plotly Graph Objects
fig = go.Figure()

fig.add_trace(go.Bar(x=distribuicao_idiomas.index, y=distribuicao_idiomas.values, text=distribuicao_idiomas.values, textposition='auto'))

fig.update_layout(title='Top 10 Idiomas',
                  xaxis_title='Idiomas', yaxis_title='Quantidade Filmes')

# Mostrando o gráfico
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e2de026b-9f9b-4aeb-8507-436304836202" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e2de026b-9f9b-4aeb-8507-436304836202")) {                    Plotly.newPlot(                        "e2de026b-9f9b-4aeb-8507-436304836202",                        [{"text":[7545.0,612.0,338.0,263.0,174.0,90.0,82.0,58.0,53.0,45.0],"textposition":"auto","x":["en","fr","it","ja","es","de","ko","zh","cn","ru"],"y":[7545,612,338,263,174,90,82,58,53,45],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidit ...

# %%
df['year'] = df['release_date'].dt.year
df['month'] = df['release_date'].dt.month
df
# Out:
#          id                       title original_language release_date  \
# 0       278    The Shawshank Redemption                en   1994-09-23
# 1       238               The Godfather                en   1972-03-14
# 2       240       The Godfather Part II                en   1974-12-20
# 3       424            Schindler's List                en   1993-12-15
# 4       389                12 Angry Men                en   1957-04-10
# ...     ...                         ...               ...          ...
# 9508  12142           Alone in the Dark                en   2005-01-28
# 9509  13805              Disaster Movie                en   2008-08-29
# 9510  11059           House of the Dead                en   2003-04-11
# 9511  14164        Dragonball Evolution                en   2009-03-12
# 9512  40016  Birdemic: Shock and Terror                en   2010-02-27
#
#       vote_average  vote_count  popularity  \
# 0            8.706       26840     150.307
# 1            8.690       20373     122.973
# 2            8.575       12291      94.204
# 3            8.565       15695      74.615
# 4            8.546        8522      54.678
# ...            ...         ...         ...
# 9508         3.251         599      11.337
# 9509         3.179        1015      19.006
# 9510         3.129         379      12.745
# 9511         2.896        2016      20.904
# 9512         2.200         331       6.548
#
#                                                overview  \
# 0     Imprisoned in the 1940s for the double murder ...
# 1     Spanning the years 1945 to 1955, a chronicle o...
# 2     In the continuing saga of the Corleone crime f...
# 3     The true story of how businessman Oskar Schind...
# 4     The defense and the prosecution have rested an...
# ...                                                 ...
# 9508  Edward Carnby is a private investigator specia...
# 9509  Over the course of one evening, an unsuspectin...
# 9510  Set on an island off the coast, a techno rave ...
# 9511  On his 18th birthday, Goku receives a mystical...
# 9512  A platoon of eagles and vultures attacks the r...
#
#                   genre_ids  \
# 0                  [18, 80]
# 1                  [18, 80]
# 2                  [18, 80]
# 3           [18, 36, 10752]
# 4                      [18]
# ...                     ...
# 9508           [28, 14, 27]
# 9509                   [35]
# 9510           [27, 28, 53]
# 9511  [28, 12, 14, 878, 53]
# 9512        [10749, 27, 53]
#
#                                                  Genres  year  month
# 0                                    ['Drama', 'Crime']  1994      9
# 1                                    ['Drama', 'Crime']  1972      3
# 2                                    ['Drama', 'Crime']  1974     12
# 3                           ['Drama', 'History', 'War']  1993     12
# 4                                             ['Drama']  1957      4
# ...                                                 ...   ...    ...
# 9508                    ['Action', 'Fantasy', 'Horror']  2005      1
# 9509                                         ['Comedy']  2008      8
# 9510                   ['Horror', 'Action', 'Thriller']  2003      4
# 9511  ['Action', 'Adventure', 'Fantasy', 'Science Fi...  2009      3
# 9512                  ['Romance', 'Horror', 'Thriller']  2010      2
#
# [9513 rows x 12 columns]

# %%
top_year = df['year'].value_counts().nlargest(20)

# Criando um gráfico de colunas usando Plotly Graph Objects
fig = go.Figure()

fig.add_trace(go.Bar(x=top_year.index, y=top_year.values, text=top_year.values, textposition='auto'))

fig.update_layout(title='Top 20 anos',
                  xaxis_title='Anos', yaxis_title='Quantidade Filmes')

# Mostrando o gráfico
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e679200c-8a52-44f9-a75f-bb78ae63bdf4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e679200c-8a52-44f9-a75f-bb78ae63bdf4")) {                    Plotly.newPlot(                        "e679200c-8a52-44f9-a75f-bb78ae63bdf4",                        [{"text":[404.0,400.0,380.0,379.0,370.0,362.0,342.0,315.0,308.0,296.0,285.0,281.0,280.0,278.0,262.0,260.0,248.0,221.0,218.0,211.0],"textposition":"auto","x":[2018,2017,2016,2019,2014,2015,2013,2021,2011,2020,2010,2009,2012,2022,2008,2007,2006,2005,2023,2004],"y":[404,400,380,379,370,362,342,315,308,296,285,281,280,278,262,260,248,221,218,211],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterp ...

# %%
top_month = df['month'].value_counts().nlargest(20)

# Criando um gráfico de colunas usando Plotly Graph Objects
fig = go.Figure()

fig.add_trace(go.Bar(x=top_month.index, y=top_month.values, text=top_month.values, textposition='auto'))

fig.update_layout(title='Top 20 meses',
                  xaxis_title='Meses', yaxis_title='Quantidade Filmes')

# Mostrando o gráfico
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4f46f4a9-6029-46fd-8cc9-fe1cea2fe364" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4f46f4a9-6029-46fd-8cc9-fe1cea2fe364")) {                    Plotly.newPlot(                        "4f46f4a9-6029-46fd-8cc9-fe1cea2fe364",                        [{"text":[1048.0,1001.0,1000.0,813.0,786.0,781.0,758.0,738.0,712.0,664.0,651.0,561.0],"textposition":"auto","x":[9,12,10,8,11,3,6,7,2,4,5,1],"y":[1048,1001,1000,813,786,781,758,738,712,664,651,561],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size": ...

# %%
# Selcionando os top 25 filmes pela nota média (vote_average)
top_25_movies = df.nlargest(25, 'vote_average')

# Criando um gráfico de colunas usando Plotly Graph Objects
fig = go.Figure()

fig.add_trace(go.Bar(x=top_25_movies['title'], y=top_25_movies['vote_average'], text=top_25_movies['vote_average'], textposition='auto'))

fig.update_layout(title='Top 25 filmes por nota média',
                  xaxis_title='Filmes', yaxis_title='Nota Média')

# Mostrando o gráfico
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9569b931-16b8-4532-b3eb-906a70d276f7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9569b931-16b8-4532-b3eb-906a70d276f7")) {                    Plotly.newPlot(                        "9569b931-16b8-4532-b3eb-906a70d276f7",                        [{"text":[8.706,8.69,8.575,8.565,8.546,8.537,8.516,8.507,8.507,8.5,8.5,8.488,8.486,8.48,8.473,8.462,8.461,8.461,8.458,8.426,8.417,8.415,8.415,8.413,8.402],"textposition":"auto","x":["The Shawshank Redemption","The Godfather","The Godfather Part II","Schindler's List","12 Angry Men","Spirited Away","The Dark Knight","Parasite","The Green Mile","Dilwale Dulhania Le Jayenge","Impossible Things","Pulp Fiction","Your Name.","The Lord of the Rings: The Return of the King","Forrest Gump","GoodFellas","The Good, the Bad and the Ugly","Seven Samurai","Grave of the Fireflies","City of God","One Flew Over the Cuckoo's Nest","Gabriel's Inferno","The Lord of the Rings: The Fellowship of the Ring","Once Upon a Time in America","Howl's Moving Castle"],"y":[8.706,8.69,8.575,8.565,8.546,8.537,8.516,8.507,8.507,8.5,8.5,8.488,8.486,8.48,8.473,8.462,8.461,8.461,8.458,8.426,8.417,8.415,8.415,8.413,8.402],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{ ...
